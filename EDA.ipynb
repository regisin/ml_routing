# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('small.csv')

# %%
data.head()
# Out:
#    frame_size frame_type  label_initial_charge  label_remaining_charge  \
# 0       534.0          I                   0.0                     0.0
# 1      1542.0          P                   0.0                     0.5
# 2       134.0          B                   0.5                     0.0
# 3       390.0          B                   0.5                     0.5
# 4       765.0          P                   0.5                     0.5
#
#    label_remaining_energy  size_1hop  size_2hop  size_3hop  \
# 0                     0.0        2.0        4.0        4.0
# 1                     0.0        2.0        4.0        4.0
# 2                     0.5        2.0        4.0        4.0
# 3                     0.5        2.0        4.0        4.0
# 4                     0.5        2.0        4.0        4.0
#
#    sum_1hop_initial_charge  sum_1hop_remaining_charge  \
# 0                    400.0                 400.000000
# 1                    400.0                 399.948736
# ...

# %%
data.describe()
# Out:
#          frame_size  label_initial_charge  label_remaining_charge  \
# count  89998.000000          89998.000000            89998.000000
# mean    3831.497667              0.003506                0.497806
# std     2258.970038              0.041720                0.033052
# min       72.000000              0.000000                0.000000
# 25%     2150.000000              0.000000                0.500000
# 50%     3267.000000              0.000000                0.500000
# 75%     5018.000000              0.000000                0.500000
# max    16745.000000              0.500000                0.500000
#
#        label_remaining_energy  size_1hop  size_2hop  size_3hop  \
# count            89998.000000    89998.0    89998.0    89998.0
# mean                 0.004645        2.0        4.0        4.0
# std                  0.047966        0.0        0.0        0.0
# min                  0.000000        2.0        4.0        4.0
# ...

# %%
data.shape
# Out:
# (89998, 17)

# %%
sns_plot = sns.pairplot(data=data)

# %%
sns_plot.savefig('output.png')
